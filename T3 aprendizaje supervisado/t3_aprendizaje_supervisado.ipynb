# %% [markdown]
# # Iteración:  Modelo de aprendizaje supervisado
#
# Para esta iteración se utlizan los datos relacionados a eventos de hurto en la ciudad de medellín y se busca predecir la cantidad de eventos utilizando redes neuronales como modelo de aprendizaje supervisado.
#
# ## Datos y preprocesamiento
#
# La temporalidad de los datos es diria para los años 2015 a 2018

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sbn
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Input, Embedding, Dense, Flatten, Dropout, concatenate, LSTM
from keras.layers import BatchNormalization, SpatialDropout1D
from keras.callbacks import Callback
from keras.models import Model
from keras.optimizers import Adam
sbn.set(rc={'figure.figsize':(10, 5)})
# Out:
# Using TensorFlow backend.

# %%
#carga de datos
datos = pd.read_excel('/home/david/Descargas/Delitos-2003-2018/Hurto.xlsx')
# filtro necesario
datos = datos[datos['Caso Hurto'] == 1]
datos.columns
# Out:
# Index(['Caso Hurto', 'Día', 'Hora Hurto', 'Minuto Hurto',
#        'Nombre Bien Sijin Hurto', 'Grupo Bien', 'Conducta Especial',
#        'Conducta', 'Modalidad', 'Sexo', 'Edad Hurto', 'Cod. Barrio', 'Barrio',
#        'Cod. Comuna', 'Comuna', 'Plana X Hurto', 'Plana Y Hurto',
#        'Geo X Hurto', 'Geo Y Hurto', 'Modelo Hurto', 'Linea Marca Hurto',
#        'Estado Civil', 'Medio Transporte', 'Medio Transporte Agresor', 'Marca',
#        'Arma Medio'],
#       dtype='object')

# %% [markdown]
# # Modelo
#
# Arquitectura de la Red neuronal
#
# Ejemplo de red neuronal
# <img src="Red-neuronal-artificial.png">
#
#
# Perceptrón de una capa
# El tipo más sencillo de red neuronal es el perceptrón de una capa, el cual consta de una sola capa de nodos de salida; las entradas están conectadas directamente a las salidas a través de una serie de ponderaciones. Es por esto que puede ser considerada el tipo más sencillo de red prealimentada. La suma de los productos de las ponderaciones y las entradas es calculada en cada nodo y, si el valor es superior a algún umbral (típicamente 0), los neurona es disparada y toma el valor de activación (típicamente 1); de forma contraria, toma el valor de desactivación (típicamente -1). Las neuronas con esta clase de función de activación son también llamadas neuronas artificiales o unidades de umbral lineal. Muchos autores usan el término perceptrón para las redes que constan de únicamente una de estas unidades.
# https://es.wikipedia.org/wiki/Red_neuronal_prealimentada
#
#
# ### Capa entrada
# 30 neuronas correspondiente a la cantidad de inputs
# ### Capas ocultas
# 1 capa oculta con 30 neuronas
# ### capa de salidad
# La salida será 1 sola neurona
# ### Función de activación
# Se utiliza tangente hiperbólica puesto que utilizaremos valores entre -1 y 1.
#
# Utilizaremos como optimizador Adam y métrica de pérdida (loss) Mean Absolute Error
# Como la predicción será un valor continuo y no discreto, para calcular el Acuracy utilizaremos Mean Squared Error y para saber si mejora con el entrenamiento se debería ir reduciendo con las EPOCHS.
#
# ### Referencia función de costo en redes neuronales:
# http://www.diegocalvo.es/funcion-de-coste-redes-neuronales/
#
# Adam
# El optimizador Adam trata de solventar el problema con la fijación de el ratio de aprendizaje del SGD (Stochastic Gradient Descent), para ello adapta el ratio de aprendizaje en función de cómo estén distribuidos los parámetros. Si los parámetros están muy dispersos (sparse) el ratio de aprendizaje aumentará.
#
# Adam es una actualización del Optimizador RMSProp (Root Mean Square Propagation) que se basa en un ratio de aprendizaje adaptativa.
#
# ### Flatten
# se realiza para convertir los datos multidimensionales en un vector de características 1D para ser utilizado por la siguiente capa que es la capa densa
#
# ### Dropout
# Técnica de regularización para reducir el sobreajuste en redes neuronales al evitar complejas adaptaciones en los datos de entrenamiento. Es una forma muy eficiente de realizar promedios de modelos con redes neuronales convolucionales (CNN). El término “abandono” se refiere al abandono de unidades (tanto ocultas como visibles) en redes neuronales.
# http://sitiobigdata.com/2018/08/28/redes-neuronales-convolucionales-vista-rapida-implementacion/

# %% [markdown]
# ## Multivariado

# %%
df = datos
df['ano']=df['Día'].dt.year
df = df[df['ano'] > 2015]

# %%
## Extracción
def group_column(data, name, group=None, func='count'):
	"""
	función para hacer agregaciones a un dataframe
	:param data: dataframe
	:param name:  string, nombre para la nueva columna
	:param group: lista o string, nombre de las columnas para agrupar
	:param func: string o numpy ej: np.sum, funcion de agregacion
	:return:
	"""
	default=['Día']
	if group:
		if type(group) == list:
			default.extend(group)
		else:
			default.append(group)
	temp = data.groupby(default).agg({'Caso Hurto': func})
	temp.columns = [name]
	df = temp.reset_index()
	df = pd.merge(data, df, how='left', on=default)
	return df, temp
df = group_column(df,'cuenta_dia')[1]
df.describe()
# Out:
#         cuenta_dia
# count  1096.000000
# mean     78.271898
# std      25.188513
# min      12.000000
# 25%      60.000000
# 50%      76.000000
# 75%      97.000000
# max     182.000000

# %%
# extracción caracterisiticas de fecha
df['dia']=[x.weekday() for x in df.index]
df['mes']=[x.month for x in df.index]
df['dia_sem']=[x.day for x in df.index]
#df['year']=[x.year for x in df.index]

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
PASOS=30
values = df['cuenta_dia'].values
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)

df['scaled'] = scaled
scaledMerge=df.drop('cuenta_dia',axis=1)

reframed = series_to_supervised(scaledMerge, PASOS, 1)
reframed.head()
# Out:
#             var1(t-30)  var2(t-30)  var3(t-30)  var4(t-30)  var1(t-29)  \
# Día
# 2017-01-31         6.0         1.0         1.0   -0.806452         0.0
# 2017-02-01         0.0         1.0         2.0   -0.470968         1.0
# 2017-02-02         1.0         1.0         3.0   -0.561290         2.0
# 2017-02-03         2.0         1.0         4.0   -0.380645         3.0
# 2017-02-04         3.0         1.0         5.0   -0.587097         4.0
#
#             var2(t-29)  var3(t-29)  var4(t-29)  var1(t-28)  var2(t-28)  ...  \
# Día                                                                     ...
# 2017-01-31         1.0         2.0   -0.470968         1.0         1.0  ...
# 2017-02-01         1.0         3.0   -0.561290         2.0         1.0  ...
# 2017-02-02         1.0         4.0   -0.380645         3.0         1.0  ...
# 2017-02-03         1.0         5.0   -0.587097         4.0         1.0  ...
# 2017-02-04         1.0         6.0   -0.329032         5.0         1.0  ...
#
#             var3(t-2)  var4(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  \
# Día
# 2017-01-31       29.0  -0.625807        0.0        1.0       30.0  -0.393548
# 2017-02-01       30.0  -0.393548        1.0        1.0       31.0  -0.483871
# 2017-02-02       31.0  -0.483871        2.0        2.0        1.0  -0.290323
# 2017-02-03        1.0  -0.290323        3.0        2.0        2.0  -0.200000
# 2017-02-04        2.0  -0.200000        4.0        2.0        3.0  -0.548387
#
#             var1(t)  var2(t)  var3(t)   var4(t)
# Día
# 2017-01-31        1        1       31 -0.483871
# 2017-02-01        2        2        1 -0.290323
# 2017-02-02        3        2        2 -0.200000
# 2017-02-03        4        2        3 -0.548387
# 2017-02-04        5        2        4 -0.587097
#
# [5 rows x 124 columns]

# %%
newReframed=reframed.drop(['var1(t)','var2(t)', 'var3(t)'],axis=1)
print(newReframed.shape)
newReframed.head()
# Out:
# (700, 121)
#             var1(t-30)  var2(t-30)  var3(t-30)  var4(t-30)  var1(t-29)  \
# Día
# 2017-01-31         6.0         1.0         1.0   -0.806452         0.0
# 2017-02-01         0.0         1.0         2.0   -0.470968         1.0
# 2017-02-02         1.0         1.0         3.0   -0.561290         2.0
# 2017-02-03         2.0         1.0         4.0   -0.380645         3.0
# 2017-02-04         3.0         1.0         5.0   -0.587097         4.0
#
#             var2(t-29)  var3(t-29)  var4(t-29)  var1(t-28)  var2(t-28)  ...  \
# Día                                                                     ...
# 2017-01-31         1.0         2.0   -0.470968         1.0         1.0  ...
# 2017-02-01         1.0         3.0   -0.561290         2.0         1.0  ...
# 2017-02-02         1.0         4.0   -0.380645         3.0         1.0  ...
# 2017-02-03         1.0         5.0   -0.587097         4.0         1.0  ...
# 2017-02-04         1.0         6.0   -0.329032         5.0         1.0  ...
#
#             var4(t-3)  var1(t-2)  var2(t-2)  var3(t-2)  var4(t-2)  var1(t-1)  \
# Día
# 2017-01-31  -0.419355        6.0        1.0       29.0  -0.625807        0.0
# 2017-02-01  -0.625807        0.0        1.0       30.0  -0.393548        1.0
# 2017-02-02  -0.393548        1.0        1.0       31.0  -0.483871        2.0
# 2017-02-03  -0.483871        2.0        2.0        1.0  -0.290323        3.0
# 2017-02-04  -0.290323        3.0        2.0        2.0  -0.200000        4.0
#
#             var2(t-1)  var3(t-1)  var4(t-1)   var4(t)
# Día
# 2017-01-31        1.0       30.0  -0.393548 -0.483871
# 2017-02-01        1.0       31.0  -0.483871 -0.290323
# 2017-02-02        2.0        1.0  -0.290323 -0.200000
# 2017-02-03        2.0        2.0  -0.200000 -0.548387
# 2017-02-04        2.0        3.0  -0.548387 -0.587097
#
# [5 rows x 121 columns]

# %%
# split into train and test sets
values = newReframed.values
n_train_days = int(len(newReframed)*.8)
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split into input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (560, 1, 120) (560,) (140, 1, 120) (140,)

# %%
neurona_entrada = 30
neurona_oculta = 3
neurona_oculta2 = 4

def crear_modeloFF():
    model = Sequential() 
    model.add(Dense(neurona_entrada, input_shape=(1,x_train.shape[2]),activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(neurona_oculta, activation='tanh'))
    #model.add(Dropout(0.5))
    #model.add(Dense(neurona_oculta2, activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mse"])
    model.summary()
    return model

# %%
EPOCHS=184
model = crear_modeloFF()

history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# Model: "sequential_75"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_281 (Dense)            (None, 1, 30)             3630
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 1, 30)             0
# _________________________________________________________________
# dense_282 (Dense)            (None, 1, 3)              93
# _________________________________________________________________
# flatten_75 (Flatten)         (None, 3)                 0
# _________________________________________________________________
# dense_283 (Dense)            (None, 1)                 4
# =================================================================
# Total params: 3,727
# Trainable params: 3,727
# Non-trainable params: 0
# _________________________________________________________________
# Train on 560 samples, validate on 140 samples
# Epoch 1/184
# 560/560 [==============================] - 0s 652us/step - loss: 0.4584 - mse: 0.3154 - val_loss: 0.3548 - val_mse: 0.1865
# Epoch 2/184
# 560/560 [==============================] - 0s 96us/step - loss: 0.3980 - mse: 0.2387 - val_loss: 0.3434 - val_mse: 0.1685
# Epoch 3/184
# 560/560 [==============================] - 0s 104us/step - loss: 0.3812 - mse: 0.2187 - val_loss: 0.3222 - val_mse: 0.1568
# Epoch 4/184
# 560/560 [==============================] - 0s 83us/step - loss: 0.3492 - mse: 0.1860 - val_loss: 0.3021 - val_mse: 0.1401
# Epoch 5/184
# 560/560 [==============================] - 0s 107us/step - loss: 0.3488 - mse: 0.1820 - val_loss: 0.3421 - val_mse: 0.1649
# Epoch 6/184
# 560/560 [==============================] - 0s 122us/step - loss: 0.3415 - mse: 0.1798 - val_loss: 0.2838 - val_mse: 0.1230
# Epoch 7/184
# 560/560 [==============================] - 0s 131us/step - loss: 0.3373 - mse: 0.1731 - val_loss: 0.4220 - val_mse: 0.2329
# Epoch 8/184
# 560/560 [==============================] - 0s 103us/step - loss: 0.3321 - mse: 0.1681 - val_loss: 0.3160 - val_mse: 0.1406
# Epoch 9/184
# 560/560 [==============================] - 0s 87us/step - loss: 0.2991 - mse: 0.1377 - val_loss: 0.3725 - val_mse: 0.1818
# Epoch 10/184
# 560/560 [==============================] - 0s 93us/step - loss: 0.3113 - mse: 0.1465 - val_loss: 0.3175 - val_mse: 0.1365
# Epoch 11/184
# 560/560 [==============================] - 0s 101us/step - loss: 0.2802 - mse: 0.1193 - val_loss: 0.3334 - val_mse: 0.1486
# Epoch 12/184
# 560/560 [==============================] - 0s 102us/step - loss: 0.2910 - mse: 0.1305 - val_loss: 0.3373 - val_mse: 0.1495
# Epoch 13/184
# 560/560 [==============================] - 0s 130us/step - loss: 0.2709 - mse: 0.1143 - val_loss: 0.3242 - val_mse: 0.1397
# Epoch 14/184
# 560/560 [==============================] - 0s 134us/step - loss: 0.2605 - mse: 0.1063 - val_loss: 0.3297 - val_mse: 0.1447
# Epoch 15/184
# 560/560 [==============================] - 0s 104us/step - loss: 0.2523 - mse: 0.0992 - val_loss: 0.3104 - val_mse: 0.1275
# Epoch 16/184
# 560/560 [==============================] - 0s 143us/step - loss: 0.2432 - mse: 0.0930 - val_loss: 0.2978 - val_mse: 0.1195
# Epoch 17/184
# 560/560 [==============================] - 0s 98us/step - loss: 0.2466 - mse: 0.0923 - val_loss: 0.3142 - val_mse: 0.1296
# Epoch 18/184
# 560/560 [==============================] - 0s 87us/step - loss: 0.2489 - mse: 0.0982 - val_loss: 0.3071 - val_mse: 0.1241
# Epoch 19/184
# 560/560 [==============================] - 0s 111us/step - loss: 0.2429 - mse: 0.0930 - val_loss: 0.3075 - val_mse: 0.1239
# Epoch 20/184
# 560/560 [==============================] - 0s 97us/step - loss: 0.2388 - mse: 0.0896 - val_loss: 0.2993 - val_mse: 0.1182
# Epoch 21/184
# 560/560 [==============================] - 0s 142us/step - loss: 0.2360 - mse: 0.0880 - val_loss: 0.2899 - val_mse: 0.1122
# Epoch 22/184
# 560/560 [==============================] - 0s 101us/step - loss: 0.2416 - mse: 0.0929 - val_loss: 0.2856 - val_mse: 0.1091
# Epoch 23/184
# 560/560 [==============================] - 0s 86us/step - loss: 0.2351 - mse: 0.0890 - val_loss: 0.2841 - val_mse: 0.1078
# Epoch 24/184
# 560/560 [==============================] - 0s 138us/step - loss: 0.2426 - mse: 0.0926 - val_loss: 0.2762 - val_mse: 0.1017
# Epoch 25/184
# 560/560 [==============================] - 0s 100us/step - loss: 0.2330 - mse: 0.0870 - val_loss: 0.2765 - val_mse: 0.1024
# Epoch 26/184
# 560/560 [==============================] - 0s 106us/step - loss: 0.2325 - mse: 0.0869 - val_loss: 0.2896 - val_mse: 0.1114
# Epoch 27/184
# 560/560 [==============================] - 0s 123us/step - loss: 0.2338 - mse: 0.0860 - val_loss: 0.2910 - val_mse: 0.1127
# Epoch 28/184
# 560/560 [==============================] - 0s 86us/step - loss: 0.2391 - mse: 0.0879 - val_loss: 0.2876 - val_mse: 0.1099
# Epoch 29/184
# 560/560 [==============================] - 0s 130us/step - loss: 0.2358 - mse: 0.0879 - val_loss: 0.2802 - val_mse: 0.1054
# Epoch 30/184
# 560/560 [==============================] - 0s 104us/step - loss: 0.2333 - mse: 0.0877 - val_loss: 0.2829 - val_mse: 0.1071
# Epoch 31/184
# 560/560 [==============================] - 0s 92us/step - loss: 0.2377 - mse: 0.0893 - val_loss: 0.2853 - val_mse: 0.1086
# Epoch 32/184
# 560/560 [==============================] - 0s 84us/step - loss: 0.2374 - mse: 0.0890 - val_loss: 0.2782 - val_mse: 0.1035
# Epoch 33/184
# 560/560 [==============================] - 0s 92us/step - loss: 0.2317 - mse: 0.0857 - val_loss: 0.2835 - val_mse: 0.1077
# Epoch 34/184
# 560/560 [==============================] - 0s 76us/step - loss: 0.2345 - mse: 0.0868 - val_loss: 0.2856 - val_mse: 0.1074
# Epoch 35/184
# 560/560 [==============================] - 0s 66us/step - loss: 0.2381 - mse: 0.0890 - val_loss: 0.2670 - val_mse: 0.0945
# Epoch 36/184
# 560/560 [==============================] - 0s 105us/step - loss: 0.2343 - mse: 0.0871 - val_loss: 0.2759 - val_mse: 0.0995
# Epoch 37/184
# 560/560 [==============================] - 0s 90us/step - loss: 0.2308 - mse: 0.0849 - val_loss: 0.2803 - val_mse: 0.1033
# Epoch 38/184
# 560/560 [==============================] - 0s 76us/step - loss: 0.2271 - mse: 0.0833 - val_loss: 0.2691 - val_mse: 0.0961
# Epoch 39/184
# 560/560 [==============================] - 0s 120us/step - loss: 0.2371 - mse: 0.0884 - val_loss: 0.2700 - val_mse: 0.0969
# Epoch 40/184
# 560/560 [==============================] - 0s 99us/step - loss: 0.2315 - mse: 0.0839 - val_loss: 0.2680 - val_mse: 0.0954
# Epoch 41/184
# 560/560 [==============================] - 0s 100us/step - loss: 0.2289 - mse: 0.0839 - val_loss: 0.2596 - val_mse: 0.0910
# Epoch 42/184
# 560/560 [==============================] - 0s 112us/step - loss: 0.2290 - mse: 0.0836 - val_loss: 0.2559 - val_mse: 0.0878
# Epoch 43/184
# 560/560 [==============================] - 0s 102us/step - loss: 0.2324 - mse: 0.0854 - val_loss: 0.2761 - val_mse: 0.1003
# Epoch 44/184
# 560/560 [==============================] - 0s 80us/step - loss: 0.2267 - mse: 0.0812 - val_loss: 0.2592 - val_mse: 0.0907
# Epoch 45/184
# 560/560 [==============================] - 0s 119us/step - loss: 0.2300 - mse: 0.0835 - val_loss: 0.2813 - val_mse: 0.1040
# Epoch 46/184
# 560/560 [==============================] - 0s 91us/step - loss: 0.2310 - mse: 0.0831 - val_loss: 0.2704 - val_mse: 0.0970
# Epoch 47/184
# 560/560 [==============================] - 0s 98us/step - loss: 0.2326 - mse: 0.0862 - val_loss: 0.2683 - val_mse: 0.0948
# Epoch 48/184
# 560/560 [==============================] - 0s 103us/step - loss: 0.2256 - mse: 0.0805 - val_loss: 0.2619 - val_mse: 0.0909
# Epoch 49/184
# 560/560 [==============================] - 0s 116us/step - loss: 0.2255 - mse: 0.0817 - val_loss: 0.2776 - val_mse: 0.0992
# Epoch 50/184
# 560/560 [==============================] - 0s 81us/step - loss: 0.2269 - mse: 0.0812 - val_loss: 0.2659 - val_mse: 0.0933
# Epoch 51/184
# 560/560 [==============================] - 0s 124us/step - loss: 0.2265 - mse: 0.0828 - val_loss: 0.2594 - val_mse: 0.0896
# Epoch 52/184
# 560/560 [==============================] - 0s 91us/step - loss: 0.2262 - mse: 0.0800 - val_loss: 0.2728 - val_mse: 0.0989
# Epoch 53/184
# 560/560 [==============================] - 0s 93us/step - loss: 0.2293 - mse: 0.0822 - val_loss: 0.2542 - val_mse: 0.0870
# Epoch 54/184
# 560/560 [==============================] - 0s 96us/step - loss: 0.2306 - mse: 0.0821 - val_loss: 0.2565 - val_mse: 0.0893
# Epoch 55/184
# 560/560 [==============================] - 0s 103us/step - loss: 0.2255 - mse: 0.0798 - val_loss: 0.2673 - val_mse: 0.0955
# Epoch 56/184
# 560/560 [==============================] - 0s 84us/step - loss: 0.2242 - mse: 0.0816 - val_loss: 0.2543 - val_mse: 0.0863
# Epoch 57/184
# 560/560 [==============================] - 0s 81us/step - loss: 0.2266 - mse: 0.0812 - val_loss: 0.2667 - val_mse: 0.0960
# Epoch 58/184
# 560/560 [==============================] - 0s 73us/step - loss: 0.2313 - mse: 0.0831 - val_loss: 0.2546 - val_mse: 0.0887
# Epoch 59/184
# 560/560 [==============================] - 0s 86us/step - loss: 0.2261 - mse: 0.0803 - val_loss: 0.2692 - val_mse: 0.0964
# Epoch 60/184
# 560/560 [==============================] - 0s 90us/step - loss: 0.2250 - mse: 0.0807 - val_loss: 0.2448 - val_mse: 0.0854
# Epoch 61/184
# 560/560 [==============================] - 0s 93us/step - loss: 0.2252 - mse: 0.0787 - val_loss: 0.2806 - val_mse: 0.1035
# Epoch 62/184
# 560/560 [==============================] - 0s 78us/step - loss: 0.2263 - mse: 0.0799 - val_loss: 0.2511 - val_mse: 0.0852
# Epoch 63/184
# 560/560 [==============================] - 0s 74us/step - loss: 0.2224 - mse: 0.0770 - val_loss: 0.2505 - val_mse: 0.0843
# Epoch 64/184
# 560/560 [==============================] - 0s 80us/step - loss: 0.2253 - mse: 0.0810 - val_loss: 0.2423 - val_mse: 0.0829
# Epoch 65/184
# 560/560 [==============================] - 0s 78us/step - loss: 0.2221 - mse: 0.0780 - val_loss: 0.2531 - val_mse: 0.0868
# Epoch 66/184
# 560/560 [==============================] - 0s 108us/step - loss: 0.2247 - mse: 0.0797 - val_loss: 0.2573 - val_mse: 0.0870
# Epoch 67/184
# 560/560 [==============================] - 0s 73us/step - loss: 0.2242 - mse: 0.0778 - val_loss: 0.2588 - val_mse: 0.0875
# Epoch 68/184
# 560/560 [==============================] - 0s 103us/step - loss: 0.2233 - mse: 0.0782 - val_loss: 0.2512 - val_mse: 0.0824
# Epoch 69/184
# 560/560 [==============================] - 0s 80us/step - loss: 0.2193 - mse: 0.0780 - val_loss: 0.2469 - val_mse: 0.0817
# Epoch 70/184
# 560/560 [==============================] - 0s 78us/step - loss: 0.2183 - mse: 0.0765 - val_loss: 0.2474 - val_mse: 0.0815
# Epoch 71/184
# 560/560 [==============================] - 0s 103us/step - loss: 0.2223 - mse: 0.0779 - val_loss: 0.2420 - val_mse: 0.0794
# Epoch 72/184
# 560/560 [==============================] - 0s 68us/step - loss: 0.2202 - mse: 0.0763 - val_loss: 0.2527 - val_mse: 0.0848
# Epoch 73/184
# 560/560 [==============================] - 0s 77us/step - loss: 0.2254 - mse: 0.0780 - val_loss: 0.2457 - val_mse: 0.0793
# Epoch 74/184
# 560/560 [==============================] - 0s 94us/step - loss: 0.2193 - mse: 0.0766 - val_loss: 0.2402 - val_mse: 0.0788
# Epoch 75/184
# 560/560 [==============================] - 0s 101us/step - loss: 0.2191 - mse: 0.0756 - val_loss: 0.2422 - val_mse: 0.0797
# Epoch 76/184
# 560/560 [==============================] - 0s 99us/step - loss: 0.2174 - mse: 0.0768 - val_loss: 0.2326 - val_mse: 0.0754
# Epoch 77/184
# 560/560 [==============================] - 0s 87us/step - loss: 0.2164 - mse: 0.0732 - val_loss: 0.2369 - val_mse: 0.0772
# Epoch 78/184
# 560/560 [==============================] - 0s 84us/step - loss: 0.2186 - mse: 0.0753 - val_loss: 0.2356 - val_mse: 0.0750
# Epoch 79/184
# 560/560 [==============================] - ETA: 0s - loss: 0.2176 - mse: 0.065 - 0s 80us/step - loss: 0.2142 - mse: 0.0743 - val_loss: 0.2387 - val_mse: 0.0772
# Epoch 80/184
# 560/560 [==============================] - 0s 79us/step - loss: 0.2063 - mse: 0.0687 - val_loss: 0.2430 - val_mse: 0.0794
# Epoch 81/184
# 560/560 [==============================] - 0s 87us/step - loss: 0.2214 - mse: 0.0770 - val_loss: 0.2480 - val_mse: 0.0849
# Epoch 82/184
# 560/560 [==============================] - 0s 76us/step - loss: 0.2171 - mse: 0.0754 - val_loss: 0.2242 - val_mse: 0.0723
# Epoch 83/184
# 560/560 [==============================] - 0s 64us/step - loss: 0.2171 - mse: 0.0727 - val_loss: 0.2338 - val_mse: 0.0755
# Epoch 84/184
# 560/560 [==============================] - 0s 78us/step - loss: 0.2174 - mse: 0.0738 - val_loss: 0.2236 - val_mse: 0.0720
# Epoch 85/184
# 560/560 [==============================] - 0s 85us/step - loss: 0.2127 - mse: 0.0746 - val_loss: 0.2470 - val_mse: 0.0827
# Epoch 86/184
# 560/560 [==============================] - 0s 64us/step - loss: 0.2199 - mse: 0.0767 - val_loss: 0.2400 - val_mse: 0.0787
# Epoch 87/184
# 560/560 [==============================] - 0s 97us/step - loss: 0.2119 - mse: 0.0715 - val_loss: 0.2336 - val_mse: 0.0753
# Epoch 88/184
# 560/560 [==============================] - 0s 78us/step - loss: 0.2100 - mse: 0.0708 - val_loss: 0.2435 - val_mse: 0.0794
# Epoch 89/184
# 560/560 [==============================] - 0s 77us/step - loss: 0.2079 - mse: 0.0688 - val_loss: 0.2194 - val_mse: 0.0706
# Epoch 90/184
# 560/560 [==============================] - 0s 74us/step - loss: 0.2211 - mse: 0.0751 - val_loss: 0.2474 - val_mse: 0.0830
# Epoch 91/184
# 560/560 [==============================] - 0s 80us/step - loss: 0.2142 - mse: 0.0729 - val_loss: 0.2190 - val_mse: 0.0693
# Epoch 92/184
# 560/560 [==============================] - 0s 98us/step - loss: 0.2080 - mse: 0.0680 - val_loss: 0.2292 - val_mse: 0.0744
# Epoch 93/184
# 560/560 [==============================] - 0s 97us/step - loss: 0.2095 - mse: 0.0703 - val_loss: 0.2225 - val_mse: 0.0711
# Epoch 94/184
# 560/560 [==============================] - 0s 78us/step - loss: 0.2079 - mse: 0.0694 - val_loss: 0.2111 - val_mse: 0.0684
# Epoch 95/184
# 560/560 [==============================] - 0s 67us/step - loss: 0.2158 - mse: 0.0738 - val_loss: 0.2146 - val_mse: 0.0674
# Epoch 96/184
# 560/560 [==============================] - 0s 87us/step - loss: 0.2113 - mse: 0.0694 - val_loss: 0.2140 - val_mse: 0.0672
# Epoch 97/184
# 560/560 [==============================] - 0s 85us/step - loss: 0.2082 - mse: 0.0692 - val_loss: 0.2152 - val_mse: 0.0689
# Epoch 98/184
# 560/560 [==============================] - 0s 75us/step - loss: 0.2024 - mse: 0.0687 - val_loss: 0.2195 - val_mse: 0.0686
# Epoch 99/184
# 560/560 [==============================] - 0s 105us/step - loss: 0.2046 - mse: 0.0684 - val_loss: 0.2092 - val_mse: 0.0644
# Epoch 100/184
# 560/560 [==============================] - 0s 84us/step - loss: 0.1962 - mse: 0.0625 - val_loss: 0.2082 - val_mse: 0.0655
# Epoch 101/184
# 560/560 [==============================] - 0s 97us/step - loss: 0.2045 - mse: 0.0693 - val_loss: 0.2130 - val_mse: 0.0679
# Epoch 102/184
# 560/560 [==============================] - 0s 65us/step - loss: 0.1987 - mse: 0.0647 - val_loss: 0.2144 - val_mse: 0.0696
# Epoch 103/184
# 560/560 [==============================] - 0s 92us/step - loss: 0.1956 - mse: 0.0622 - val_loss: 0.2118 - val_mse: 0.0672
# Epoch 104/184
# 560/560 [==============================] - 0s 88us/step - loss: 0.1956 - mse: 0.0613 - val_loss: 0.2264 - val_mse: 0.0722
# Epoch 105/184
# 560/560 [==============================] - 0s 88us/step - loss: 0.2024 - mse: 0.0661 - val_loss: 0.2066 - val_mse: 0.0663
# Epoch 106/184
# 560/560 [==============================] - 0s 83us/step - loss: 0.1974 - mse: 0.0621 - val_loss: 0.2049 - val_mse: 0.0669
# Epoch 107/184
# 560/560 [==============================] - 0s 73us/step - loss: 0.1996 - mse: 0.0671 - val_loss: 0.2063 - val_mse: 0.0645
# Epoch 108/184
# 560/560 [==============================] - 0s 78us/step - loss: 0.1928 - mse: 0.0615 - val_loss: 0.2108 - val_mse: 0.0668
# Epoch 109/184
# 560/560 [==============================] - 0s 94us/step - loss: 0.1890 - mse: 0.0609 - val_loss: 0.2054 - val_mse: 0.0650
# Epoch 110/184
# 560/560 [==============================] - 0s 88us/step - loss: 0.1923 - mse: 0.0618 - val_loss: 0.2102 - val_mse: 0.0657
# Epoch 111/184
# 560/560 [==============================] - 0s 91us/step - loss: 0.1938 - mse: 0.0622 - val_loss: 0.2050 - val_mse: 0.0641
# Epoch 112/184
# 560/560 [==============================] - 0s 82us/step - loss: 0.1932 - mse: 0.0630 - val_loss: 0.1992 - val_mse: 0.0602
# Epoch 113/184
# 560/560 [==============================] - 0s 92us/step - loss: 0.1941 - mse: 0.0601 - val_loss: 0.1990 - val_mse: 0.0620
# Epoch 114/184
# 560/560 [==============================] - 0s 76us/step - loss: 0.1925 - mse: 0.0611 - val_loss: 0.2083 - val_mse: 0.0654
# Epoch 115/184
# 560/560 [==============================] - 0s 109us/step - loss: 0.1876 - mse: 0.0598 - val_loss: 0.2008 - val_mse: 0.0628
# Epoch 116/184
# 560/560 [==============================] - 0s 104us/step - loss: 0.1911 - mse: 0.0610 - val_loss: 0.1970 - val_mse: 0.0595
# Epoch 117/184
# 560/560 [==============================] - 0s 79us/step - loss: 0.1851 - mse: 0.0576 - val_loss: 0.2077 - val_mse: 0.0654
# Epoch 118/184
# 560/560 [==============================] - 0s 79us/step - loss: 0.1914 - mse: 0.0609 - val_loss: 0.1943 - val_mse: 0.0592
# Epoch 119/184
# 560/560 [==============================] - 0s 72us/step - loss: 0.1830 - mse: 0.0549 - val_loss: 0.1974 - val_mse: 0.0620
# Epoch 120/184
# 560/560 [==============================] - 0s 93us/step - loss: 0.1827 - mse: 0.0558 - val_loss: 0.1944 - val_mse: 0.0585
# Epoch 121/184
# 560/560 [==============================] - 0s 98us/step - loss: 0.1850 - mse: 0.0579 - val_loss: 0.1983 - val_mse: 0.0626
# Epoch 122/184
# 560/560 [==============================] - 0s 79us/step - loss: 0.1908 - mse: 0.0614 - val_loss: 0.1946 - val_mse: 0.0589
# Epoch 123/184
# 560/560 [==============================] - 0s 115us/step - loss: 0.1810 - mse: 0.0547 - val_loss: 0.1961 - val_mse: 0.0620
# Epoch 124/184
# 560/560 [==============================] - 0s 85us/step - loss: 0.1858 - mse: 0.0573 - val_loss: 0.1899 - val_mse: 0.0573
# Epoch 125/184
# 560/560 [==============================] - 0s 60us/step - loss: 0.1744 - mse: 0.0519 - val_loss: 0.1968 - val_mse: 0.0612
# Epoch 126/184
# 560/560 [==============================] - 0s 107us/step - loss: 0.1813 - mse: 0.0551 - val_loss: 0.1985 - val_mse: 0.0610
# Epoch 127/184
# 560/560 [==============================] - 0s 82us/step - loss: 0.1815 - mse: 0.0528 - val_loss: 0.2017 - val_mse: 0.0631
# Epoch 128/184
# 560/560 [==============================] - 0s 85us/step - loss: 0.1730 - mse: 0.0512 - val_loss: 0.1882 - val_mse: 0.0573
# Epoch 129/184
# 560/560 [==============================] - 0s 89us/step - loss: 0.1727 - mse: 0.0506 - val_loss: 0.1957 - val_mse: 0.0596
# Epoch 130/184
# 560/560 [==============================] - 0s 87us/step - loss: 0.1720 - mse: 0.0496 - val_loss: 0.1824 - val_mse: 0.0540
# Epoch 131/184
# 560/560 [==============================] - 0s 89us/step - loss: 0.1724 - mse: 0.0508 - val_loss: 0.1889 - val_mse: 0.0579
# Epoch 132/184
# 560/560 [==============================] - 0s 85us/step - loss: 0.1692 - mse: 0.0498 - val_loss: 0.1884 - val_mse: 0.0558
# Epoch 133/184
# 560/560 [==============================] - 0s 78us/step - loss: 0.1707 - mse: 0.0492 - val_loss: 0.1813 - val_mse: 0.0542
# Epoch 134/184
# 560/560 [==============================] - 0s 68us/step - loss: 0.1699 - mse: 0.0486 - val_loss: 0.1836 - val_mse: 0.0559
# Epoch 135/184
# 560/560 [==============================] - 0s 92us/step - loss: 0.1718 - mse: 0.0492 - val_loss: 0.1808 - val_mse: 0.0541
# Epoch 136/184
# 560/560 [==============================] - 0s 86us/step - loss: 0.1707 - mse: 0.0490 - val_loss: 0.1892 - val_mse: 0.0575
# Epoch 137/184
# 560/560 [==============================] - 0s 92us/step - loss: 0.1745 - mse: 0.0503 - val_loss: 0.1811 - val_mse: 0.0539
# Epoch 138/184
# 560/560 [==============================] - 0s 88us/step - loss: 0.1734 - mse: 0.0513 - val_loss: 0.1874 - val_mse: 0.0569
# Epoch 139/184
# 560/560 [==============================] - 0s 72us/step - loss: 0.1686 - mse: 0.0498 - val_loss: 0.1831 - val_mse: 0.0571
# Epoch 140/184
# 560/560 [==============================] - 0s 91us/step - loss: 0.1715 - mse: 0.0509 - val_loss: 0.1834 - val_mse: 0.0566
# Epoch 141/184
# 560/560 [==============================] - 0s 99us/step - loss: 0.1674 - mse: 0.0484 - val_loss: 0.1790 - val_mse: 0.0532
# Epoch 142/184
# 560/560 [==============================] - 0s 83us/step - loss: 0.1644 - mse: 0.0462 - val_loss: 0.1831 - val_mse: 0.0568
# Epoch 143/184
# 560/560 [==============================] - 0s 93us/step - loss: 0.1626 - mse: 0.0452 - val_loss: 0.1794 - val_mse: 0.0537
# Epoch 144/184
# 560/560 [==============================] - 0s 72us/step - loss: 0.1664 - mse: 0.0482 - val_loss: 0.1831 - val_mse: 0.0548
# Epoch 145/184
# 560/560 [==============================] - 0s 79us/step - loss: 0.1635 - mse: 0.0463 - val_loss: 0.1758 - val_mse: 0.0530
# Epoch 146/184
# 560/560 [==============================] - 0s 86us/step - loss: 0.1688 - mse: 0.0488 - val_loss: 0.1832 - val_mse: 0.0557
# Epoch 147/184
# 560/560 [==============================] - 0s 91us/step - loss: 0.1678 - mse: 0.0476 - val_loss: 0.1822 - val_mse: 0.0560
# Epoch 148/184
# 560/560 [==============================] - 0s 110us/step - loss: 0.1614 - mse: 0.0451 - val_loss: 0.1766 - val_mse: 0.0529
# Epoch 149/184
# 560/560 [==============================] - 0s 84us/step - loss: 0.1640 - mse: 0.0458 - val_loss: 0.1825 - val_mse: 0.0553
# Epoch 150/184
# 560/560 [==============================] - 0s 80us/step - loss: 0.1615 - mse: 0.0455 - val_loss: 0.1803 - val_mse: 0.0559
# Epoch 151/184
# 560/560 [==============================] - 0s 96us/step - loss: 0.1606 - mse: 0.0447 - val_loss: 0.1766 - val_mse: 0.0527
# Epoch 152/184
# 560/560 [==============================] - 0s 82us/step - loss: 0.1609 - mse: 0.0457 - val_loss: 0.1865 - val_mse: 0.0592
# Epoch 153/184
# 560/560 [==============================] - 0s 79us/step - loss: 0.1667 - mse: 0.0497 - val_loss: 0.1787 - val_mse: 0.0548
# Epoch 154/184
# 560/560 [==============================] - 0s 102us/step - loss: 0.1643 - mse: 0.0464 - val_loss: 0.1791 - val_mse: 0.0549
# Epoch 155/184
# 560/560 [==============================] - 0s 82us/step - loss: 0.1621 - mse: 0.0446 - val_loss: 0.1765 - val_mse: 0.0541
# Epoch 156/184
# 560/560 [==============================] - 0s 69us/step - loss: 0.1600 - mse: 0.0446 - val_loss: 0.1762 - val_mse: 0.0560
# Epoch 157/184
# 560/560 [==============================] - 0s 81us/step - loss: 0.1581 - mse: 0.0424 - val_loss: 0.1732 - val_mse: 0.0525
# Epoch 158/184
# 560/560 [==============================] - 0s 75us/step - loss: 0.1613 - mse: 0.0459 - val_loss: 0.1776 - val_mse: 0.0556
# Epoch 159/184
# 560/560 [==============================] - 0s 76us/step - loss: 0.1628 - mse: 0.0446 - val_loss: 0.1748 - val_mse: 0.0539
# Epoch 160/184
# 560/560 [==============================] - 0s 95us/step - loss: 0.1575 - mse: 0.0439 - val_loss: 0.1783 - val_mse: 0.0549
# Epoch 161/184
# 560/560 [==============================] - 0s 92us/step - loss: 0.1644 - mse: 0.0467 - val_loss: 0.1801 - val_mse: 0.0540
# Epoch 162/184
# 560/560 [==============================] - 0s 83us/step - loss: 0.1599 - mse: 0.0445 - val_loss: 0.1734 - val_mse: 0.0524
# Epoch 163/184
# 560/560 [==============================] - 0s 65us/step - loss: 0.1596 - mse: 0.0443 - val_loss: 0.1793 - val_mse: 0.0552
# Epoch 164/184
# 560/560 [==============================] - 0s 83us/step - loss: 0.1563 - mse: 0.0437 - val_loss: 0.1807 - val_mse: 0.0554
# Epoch 165/184
# 560/560 [==============================] - 0s 90us/step - loss: 0.1556 - mse: 0.0437 - val_loss: 0.1732 - val_mse: 0.0530
# Epoch 166/184
# 560/560 [==============================] - 0s 81us/step - loss: 0.1574 - mse: 0.0428 - val_loss: 0.1846 - val_mse: 0.0559
# Epoch 167/184
# 560/560 [==============================] - 0s 106us/step - loss: 0.1590 - mse: 0.0446 - val_loss: 0.1753 - val_mse: 0.0536
# Epoch 168/184
# 560/560 [==============================] - 0s 81us/step - loss: 0.1637 - mse: 0.0452 - val_loss: 0.1745 - val_mse: 0.0525
# Epoch 169/184
# 560/560 [==============================] - 0s 79us/step - loss: 0.1601 - mse: 0.0441 - val_loss: 0.1773 - val_mse: 0.0552
# Epoch 170/184
# 560/560 [==============================] - 0s 71us/step - loss: 0.1576 - mse: 0.0442 - val_loss: 0.1722 - val_mse: 0.0523
# Epoch 171/184
# 560/560 [==============================] - 0s 90us/step - loss: 0.1537 - mse: 0.0417 - val_loss: 0.1764 - val_mse: 0.0554
# Epoch 172/184
# 560/560 [==============================] - 0s 91us/step - loss: 0.1541 - mse: 0.0435 - val_loss: 0.1729 - val_mse: 0.0540
# Epoch 173/184
# 560/560 [==============================] - 0s 94us/step - loss: 0.1574 - mse: 0.0433 - val_loss: 0.1734 - val_mse: 0.0529
# Epoch 174/184
# 560/560 [==============================] - 0s 81us/step - loss: 0.1564 - mse: 0.0429 - val_loss: 0.1714 - val_mse: 0.0525
# Epoch 175/184
# 560/560 [==============================] - 0s 87us/step - loss: 0.1663 - mse: 0.0486 - val_loss: 0.1779 - val_mse: 0.0565
# Epoch 176/184
# 560/560 [==============================] - 0s 88us/step - loss: 0.1553 - mse: 0.0416 - val_loss: 0.1719 - val_mse: 0.0534
# Epoch 177/184
# 560/560 [==============================] - 0s 72us/step - loss: 0.1585 - mse: 0.0447 - val_loss: 0.1795 - val_mse: 0.0526
# Epoch 178/184
# 560/560 [==============================] - 0s 104us/step - loss: 0.1548 - mse: 0.0426 - val_loss: 0.1707 - val_mse: 0.0512
# Epoch 179/184
# 560/560 [==============================] - 0s 76us/step - loss: 0.1569 - mse: 0.0442 - val_loss: 0.1726 - val_mse: 0.0507
# Epoch 180/184
# 560/560 [==============================] - 0s 95us/step - loss: 0.1564 - mse: 0.0441 - val_loss: 0.1700 - val_mse: 0.0517
# Epoch 181/184
# 560/560 [==============================] - 0s 95us/step - loss: 0.1542 - mse: 0.0431 - val_loss: 0.1753 - val_mse: 0.0543
# Epoch 182/184
# 560/560 [==============================] - 0s 81us/step - loss: 0.1514 - mse: 0.0405 - val_loss: 0.1796 - val_mse: 0.0583
# Epoch 183/184
# 560/560 [==============================] - 0s 70us/step - loss: 0.1538 - mse: 0.0427 - val_loss: 0.1704 - val_mse: 0.0525
# Epoch 184/184
# 560/560 [==============================] - 0s 89us/step - loss: 0.1557 - mse: 0.0436 - val_loss: 0.1744 - val_mse: 0.0523

# %%
#loss: 0.1286 - mse: 0.0298 - val_loss: 0.1728 - val_mse: 0.0531   drop 0.15 pasos 30 2015
results=model.predict(x_val)

compara = pd.DataFrame(np.array([y_val, [x[0] for x in results]])).transpose()
compara.columns = ['real', 'prediccion']

inverted = scaler.inverse_transform(compara.values)

compara2 = pd.DataFrame(inverted)
compara2.columns = ['real', 'prediccion']
compara2['diferencia'] = compara2['real'] - compara2['prediccion']
compara2.head(10)
# Out:
#          real  prediccion  diferencia
# 0   98.000000  110.184052  -12.184052
# 1  134.000004  111.186376   22.813628
# 2  102.999996  115.610556  -12.610561
# 3  126.000002  113.344380   12.655622
# 4  106.000002  111.124624   -5.124622
# 5   57.000002   86.144959  -29.144957
# 6   57.000002   92.039841  -35.039839
# 7  101.999997  102.715320   -0.715324
# 8  102.999996  102.773327    0.226669
# 9  119.999998  101.576489   18.423509

# %%
compara2.describe()
# Out:
#              real  prediccion  diferencia
# count  140.000000  140.000000  140.000000
# mean    99.378571   98.137499    1.241072
# std     22.834238   12.659616   17.736125
# min     30.000000   61.396995  -64.765464
# 25%     86.750002   92.429785   -8.765396
# 50%    103.500000  102.718914    1.183342
# 75%    111.999997  105.711165   12.684633
# max    157.000001  115.610556   45.892120

# %%
results=model.predict(x_val)
window = 60
plt.scatter(range(len(y_val[-window:])),y_val[-window:],c='b')
plt.scatter(range(len(results[-window:])),results[-window:],c='orange')
plt.title('validate')
plt.show()
compara2['real'][len(compara2)-window:].plot()
compara2['prediccion'][len(compara2)-window:].plot()

# %%
#plt.ylim(5, 30)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('validate loss')
plt.show()

# %%
#plt.ylim(150, 1000)
plt.title('Accuracy')
plt.plot(history.history['mse'])

plt.plot(history.history['val_mse'])
plt.show()

# %%
min(history.history['val_mse'])
# Out:
# 0.0506744310259819

# %% [markdown]
# # Embeddings

# %%
df = datos
df['ano']=df['Día'].dt.year
df = df[df['ano'] > 2015]
#df = df[df['ano'] < 2018]

## Extracción
def group_column(data, name, group=None, func='count'):
	"""
	función para hacer agregaciones a un dataframe
	:param data: dataframe
	:param name:  string, nombre para la nueva columna
	:param group: lista o string, nombre de las columnas para agrupar
	:param func: string o numpy ej: np.sum, funcion de agregacion
	:return:
	"""
	default=['Día']
	if group:
		if type(group) == list:
			default.extend(group)
		else:
			default.append(group)
	temp = data.groupby(default).agg({'Caso Hurto': func})
	temp.columns = [name]
	df = temp.reset_index()
	df = pd.merge(data, df, how='left', on=default)
	return df, temp
df = group_column(df,'cuenta_dia')[1]
df.describe()
# Out:
#         cuenta_dia
# count  1096.000000
# mean     78.271898
# std      25.188513
# min      12.000000
# 25%      60.000000
# 50%      76.000000
# 75%      97.000000
# max     182.000000

# %%
df['dia']=[x.weekday() for x in df.index]
df['mes']=[x.month for x in df.index]
#df['dia_sem']=[x.day for x in df.index]
df['year']=[x.year for x in df.index]

df.head()
# Out:
#             cuenta_dia  dia  mes  year
# Día
# 2016-01-01          33    4    1  2016
# 2016-01-02          37    5    1  2016
# 2016-01-03          34    6    1  2016
# 2016-01-04          50    0    1  2016
# 2016-01-05          39    1    1  2016

# %%
PASOS=14
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# load dataset
values = df['cuenta_dia'].values

# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))

values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension

scaled = scaler.fit_transform(values)

reframed = series_to_supervised(scaled, PASOS, 1)
reframed.reset_index(inplace=True, drop=True)

contador=0
reframed['dia']=df['dia']
reframed['mes']=df['mes']
reframed['year']=df['year']
#reframed['dia_sem']=df['dia_sem']

for i in range(reframed.index[0],reframed.index[-1]):
    reframed['dia'].loc[contador]=df['dia'][i+8]
    reframed['mes'].loc[contador]=df['mes'][i+8]
    reframed['year'].loc[contador]=df['year'][i+8]
    #reframed['dia_sem'].loc[contador]=df['dia_sem'][i+8]
    contador=contador+1
reframed.head()
# Out:
# /home/david/jupyternot/local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#    var1(t-14)  var1(t-13)  var1(t-12)  var1(t-11)  var1(t-10)  var1(t-9)  \
# 0   -0.752941   -0.705882   -0.741176   -0.552941   -0.682353  -0.623529
# 1   -0.705882   -0.741176   -0.552941   -0.682353   -0.623529  -0.411765
# 2   -0.741176   -0.552941   -0.682353   -0.623529   -0.411765  -0.400000
# 3   -0.552941   -0.682353   -0.623529   -0.411765   -0.400000  -0.670588
# 4   -0.682353   -0.623529   -0.411765   -0.400000   -0.670588  -0.776471
#
#    var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  \
# 0  -0.411765  -0.400000  -0.670588  -0.776471  -0.717647  -0.541176
# 1  -0.400000  -0.670588  -0.776471  -0.717647  -0.541176  -0.517647
# 2  -0.670588  -0.776471  -0.717647  -0.541176  -0.517647  -0.470588
# 3  -0.776471  -0.717647  -0.541176  -0.517647  -0.470588  -0.400000
# 4  -0.717647  -0.541176  -0.517647  -0.470588  -0.400000  -0.505882
#
#    var1(t-2)  var1(t-1)   var1(t)  dia  mes    year
# 0  -0.517647  -0.470588 -0.400000  5.0  1.0  2016.0
# 1  -0.470588  -0.400000 -0.505882  6.0  1.0  2016.0
# 2  -0.400000  -0.505882 -0.800000  0.0  1.0  2016.0
# 3  -0.505882  -0.800000 -0.647059  1.0  1.0  2016.0
# 4  -0.800000  -0.647059 -0.670588  2.0  1.0  2016.0

# %%
val= reframed.columns[-3:].append(reframed.columns[:-3])
reordenado=reframed[val].copy()
reordenado.dropna(inplace=True)
reordenado
# Out:
#       dia   mes    year  var1(t-14)  var1(t-13)  var1(t-12)  var1(t-11)  \
# 0     5.0   1.0  2016.0   -0.752941   -0.705882   -0.741176   -0.552941
# 1     6.0   1.0  2016.0   -0.705882   -0.741176   -0.552941   -0.682353
# 2     0.0   1.0  2016.0   -0.741176   -0.552941   -0.682353   -0.623529
# 3     1.0   1.0  2016.0   -0.552941   -0.682353   -0.623529   -0.411765
# 4     2.0   1.0  2016.0   -0.682353   -0.623529   -0.411765   -0.400000
# ...   ...   ...     ...         ...         ...         ...         ...
# 1076  3.0  12.0  2018.0    0.023529    0.223529    0.011765    0.152941
# 1077  4.0  12.0  2018.0    0.223529    0.011765    0.152941   -0.188235
# 1078  5.0  12.0  2018.0    0.011765    0.152941   -0.188235    0.211765
# 1079  6.0  12.0  2018.0    0.152941   -0.188235    0.211765    0.129412
# 1080  0.0  12.0  2018.0   -0.188235    0.211765    0.129412   -0.117647
#
#       var1(t-10)  var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  \
# 0      -0.682353  -0.623529  -0.411765  -0.400000  -0.670588  -0.776471
# 1      -0.623529  -0.411765  -0.400000  -0.670588  -0.776471  -0.717647
# 2      -0.411765  -0.400000  -0.670588  -0.776471  -0.717647  -0.541176
# 3      -0.400000  -0.670588  -0.776471  -0.717647  -0.541176  -0.517647
# 4      -0.670588  -0.776471  -0.717647  -0.541176  -0.517647  -0.470588
# ...          ...        ...        ...        ...        ...        ...
# 1076   -0.188235   0.211765   0.129412  -0.117647   0.105882  -0.047059
# 1077    0.211765   0.129412  -0.117647   0.105882  -0.047059   0.047059
# 1078    0.129412  -0.117647   0.105882  -0.047059   0.047059  -0.258824
# 1079   -0.117647   0.105882  -0.047059   0.047059  -0.258824  -0.011765
# 1080    0.105882  -0.047059   0.047059  -0.258824  -0.011765  -0.788235
#
#       var1(t-4)  var1(t-3)  var1(t-2)  var1(t-1)   var1(t)
# 0     -0.717647  -0.541176  -0.517647  -0.470588 -0.400000
# 1     -0.541176  -0.517647  -0.470588  -0.400000 -0.505882
# 2     -0.517647  -0.470588  -0.400000  -0.505882 -0.800000
# 3     -0.470588  -0.400000  -0.505882  -0.800000 -0.647059
# 4     -0.400000  -0.505882  -0.800000  -0.647059 -0.670588
# ...         ...        ...        ...        ...       ...
# 1076   0.047059  -0.258824  -0.011765  -0.788235 -0.411765
# 1077  -0.258824  -0.011765  -0.788235  -0.411765  0.000000
# 1078  -0.011765  -0.788235  -0.411765   0.000000 -0.129412
# 1079  -0.788235  -0.411765   0.000000  -0.129412 -0.211765
# 1080  -0.411765   0.000000  -0.129412  -0.211765 -0.517647
#
# [1081 rows x 18 columns]

# %%
training_data = reordenado.drop('var1(t)',axis=1)#.values
target_data=reordenado['var1(t)']
#training_data.head()
valid_data = training_data[len(df)-151:]
valid_target=target_data[len(df)-151:]

training_data = training_data[0:len(df)]
target_data=target_data[0:len(df)]
print(training_data.shape,target_data.shape,valid_data.shape,valid_target.shape)
#training_data.head()
# Out:
# (1081, 17) (1081,) (136, 17) (136,)

# %%
def crear_modeloEmbeddings():
    emb_dias = 30 #tamanio profundidad de embeddings
    #emb_dia_sem = 30
    emb_meses = 180
    emb_year = 365

    in_dias = Input(shape=[1], name = 'dias')
    emb_dias = Embedding(7+1, emb_dias)(in_dias)
    #emb_dias = SpatialDropout1D(0.2)(emb_dias)
    in_meses = Input(shape=[1], name = 'meses')
    emb_meses = Embedding(12+1, emb_meses)(in_meses)
    emb_meses = SpatialDropout1D(0.95)(emb_meses)
    in_year = Input(shape=[1], name = 'year')
    emb_year = Embedding(2018+1, emb_year)(in_year)
    emb_year = SpatialDropout1D(0.95)(emb_year)
    in_cli = Input(shape=[PASOS], name = 'cli')
    fe = concatenate([(emb_dias), (emb_meses), (emb_year)])
    x = Flatten()(fe)
    x = Dense(PASOS,activation='tanh')(x)
    outp = Dense(1,activation='tanh')(x)
    model = Model(inputs=[in_dias,in_meses, in_year, in_cli], outputs=outp)

    model.compile(loss='mean_absolute_error', 
                  optimizer='adam',
                  metrics=['mse'])

    model.summary()
    return model

# %%
EPOCHS=64

model = crear_modeloEmbeddings()

continuas=training_data[training_data.columns[3:]]
valid_continuas=valid_data[training_data.columns[3:]]

history=model.fit([training_data['dia'],training_data['mes'], training_data['year'], continuas], target_data, epochs=EPOCHS
                 ,validation_data=([valid_data['dia'],valid_data['mes'], valid_data['year'], valid_continuas],valid_target))
# Out:
# WARNING:tensorflow:Large dropout rate: 0.95 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.95 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# meses (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# year (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# dias (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 180)       2340        meses[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 365)       736935      year[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 30)        240         dias[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 1, 180)       0           embedding_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 1, 365)       0           embedding_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1, 575)       0           embedding_1[0][0]
#                                                                  spatial_dropout1d_1[0][0]
#                                                                  spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 575)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 14)           8064        flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            15          dense_3[0][0]
# ==================================================================================================
# Total params: 747,594
# Trainable params: 747,594
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /home/david/jupyternot/local/lib/python3.5/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 1081 samples, validate on 136 samples
# Epoch 1/64
# 1081/1081 [==============================] - 1s 674us/step - loss: 0.2490 - mse: 0.0965 - val_loss: 0.1869 - val_mse: 0.0559
# Epoch 2/64
# 1081/1081 [==============================] - 0s 305us/step - loss: 0.1979 - mse: 0.0646 - val_loss: 0.1474 - val_mse: 0.0375
# Epoch 3/64
# 1081/1081 [==============================] - 0s 307us/step - loss: 0.1710 - mse: 0.0503 - val_loss: 0.1459 - val_mse: 0.0375
# Epoch 4/64
# 1081/1081 [==============================] - 0s 330us/step - loss: 0.1613 - mse: 0.0448 - val_loss: 0.1359 - val_mse: 0.0351
# Epoch 5/64
# 1081/1081 [==============================] - 0s 434us/step - loss: 0.1553 - mse: 0.0422 - val_loss: 0.1363 - val_mse: 0.0361
# Epoch 6/64
# 1081/1081 [==============================] - 0s 415us/step - loss: 0.1538 - mse: 0.0408 - val_loss: 0.1360 - val_mse: 0.0351
# Epoch 7/64
# 1081/1081 [==============================] - 0s 345us/step - loss: 0.1529 - mse: 0.0414 - val_loss: 0.1365 - val_mse: 0.0373
# Epoch 8/64
# 1081/1081 [==============================] - 0s 313us/step - loss: 0.1542 - mse: 0.0417 - val_loss: 0.1361 - val_mse: 0.0358
# Epoch 9/64
# 1081/1081 [==============================] - 0s 314us/step - loss: 0.1450 - mse: 0.0373 - val_loss: 0.1380 - val_mse: 0.0375
# Epoch 10/64
# 1081/1081 [==============================] - 0s 310us/step - loss: 0.1455 - mse: 0.0382 - val_loss: 0.1355 - val_mse: 0.0364
# Epoch 11/64
# 1081/1081 [==============================] - 0s 319us/step - loss: 0.1477 - mse: 0.0382 - val_loss: 0.1372 - val_mse: 0.0379
# Epoch 12/64
# 1081/1081 [==============================] - 0s 317us/step - loss: 0.1472 - mse: 0.0382 - val_loss: 0.1351 - val_mse: 0.0358
# Epoch 13/64
# 1081/1081 [==============================] - 0s 322us/step - loss: 0.1416 - mse: 0.0359 - val_loss: 0.1364 - val_mse: 0.0356
# Epoch 14/64
# 1081/1081 [==============================] - 0s 312us/step - loss: 0.1463 - mse: 0.0372 - val_loss: 0.1342 - val_mse: 0.0357
# Epoch 15/64
# 1081/1081 [==============================] - 0s 324us/step - loss: 0.1425 - mse: 0.0363 - val_loss: 0.1345 - val_mse: 0.0357
# Epoch 16/64
# 1081/1081 [==============================] - 0s 298us/step - loss: 0.1455 - mse: 0.0377 - val_loss: 0.1349 - val_mse: 0.0365
# Epoch 17/64
# 1081/1081 [==============================] - 0s 331us/step - loss: 0.1438 - mse: 0.0371 - val_loss: 0.1351 - val_mse: 0.0353
# Epoch 18/64
# 1081/1081 [==============================] - 0s 311us/step - loss: 0.1446 - mse: 0.0372 - val_loss: 0.1349 - val_mse: 0.0361
# Epoch 19/64
# 1081/1081 [==============================] - 0s 318us/step - loss: 0.1435 - mse: 0.0366 - val_loss: 0.1354 - val_mse: 0.0366
# Epoch 20/64
# 1081/1081 [==============================] - 0s 310us/step - loss: 0.1438 - mse: 0.0366 - val_loss: 0.1355 - val_mse: 0.0355
# Epoch 21/64
# 1081/1081 [==============================] - 0s 387us/step - loss: 0.1400 - mse: 0.0352 - val_loss: 0.1340 - val_mse: 0.0361
# Epoch 22/64
# 1081/1081 [==============================] - 0s 362us/step - loss: 0.1414 - mse: 0.0359 - val_loss: 0.1336 - val_mse: 0.0354
# Epoch 23/64
# 1081/1081 [==============================] - 0s 313us/step - loss: 0.1396 - mse: 0.0348 - val_loss: 0.1346 - val_mse: 0.0361
# Epoch 24/64
# 1081/1081 [==============================] - 1s 471us/step - loss: 0.1383 - mse: 0.0347 - val_loss: 0.1374 - val_mse: 0.0379
# Epoch 25/64
# 1081/1081 [==============================] - 0s 390us/step - loss: 0.1385 - mse: 0.0352 - val_loss: 0.1344 - val_mse: 0.0360
# Epoch 26/64
# 1081/1081 [==============================] - 0s 362us/step - loss: 0.1415 - mse: 0.0359 - val_loss: 0.1348 - val_mse: 0.0365
# Epoch 27/64
# 1081/1081 [==============================] - 0s 307us/step - loss: 0.1398 - mse: 0.0353 - val_loss: 0.1349 - val_mse: 0.0368
# Epoch 28/64
# 1081/1081 [==============================] - 0s 308us/step - loss: 0.1410 - mse: 0.0355 - val_loss: 0.1351 - val_mse: 0.0370
# Epoch 29/64
# 1081/1081 [==============================] - 0s 299us/step - loss: 0.1378 - mse: 0.0348 - val_loss: 0.1344 - val_mse: 0.0367
# Epoch 30/64
# 1081/1081 [==============================] - 0s 300us/step - loss: 0.1361 - mse: 0.0338 - val_loss: 0.1348 - val_mse: 0.0366
# Epoch 31/64
# 1081/1081 [==============================] - 0s 305us/step - loss: 0.1396 - mse: 0.0345 - val_loss: 0.1361 - val_mse: 0.0373
# Epoch 32/64
# 1081/1081 [==============================] - 0s 301us/step - loss: 0.1389 - mse: 0.0341 - val_loss: 0.1358 - val_mse: 0.0370
# Epoch 33/64
# 1081/1081 [==============================] - 0s 307us/step - loss: 0.1381 - mse: 0.0343 - val_loss: 0.1363 - val_mse: 0.0372
# Epoch 34/64
# 1081/1081 [==============================] - 0s 302us/step - loss: 0.1343 - mse: 0.0324 - val_loss: 0.1357 - val_mse: 0.0368
# Epoch 35/64
# 1081/1081 [==============================] - 0s 295us/step - loss: 0.1402 - mse: 0.0353 - val_loss: 0.1356 - val_mse: 0.0368
# Epoch 36/64
# 1081/1081 [==============================] - 0s 306us/step - loss: 0.1352 - mse: 0.0343 - val_loss: 0.1356 - val_mse: 0.0370
# Epoch 37/64
# 1081/1081 [==============================] - 0s 300us/step - loss: 0.1403 - mse: 0.0358 - val_loss: 0.1372 - val_mse: 0.0380
# Epoch 38/64
# 1081/1081 [==============================] - 0s 295us/step - loss: 0.1347 - mse: 0.0338 - val_loss: 0.1366 - val_mse: 0.0377
# Epoch 39/64
# 1081/1081 [==============================] - 0s 310us/step - loss: 0.1373 - mse: 0.0338 - val_loss: 0.1366 - val_mse: 0.0375
# Epoch 40/64
# 1081/1081 [==============================] - 0s 310us/step - loss: 0.1384 - mse: 0.0344 - val_loss: 0.1371 - val_mse: 0.0378
# Epoch 41/64
# 1081/1081 [==============================] - 0s 301us/step - loss: 0.1378 - mse: 0.0346 - val_loss: 0.1348 - val_mse: 0.0363
# Epoch 42/64
# 1081/1081 [==============================] - 0s 300us/step - loss: 0.1373 - mse: 0.0344 - val_loss: 0.1367 - val_mse: 0.0375
# Epoch 43/64
# 1081/1081 [==============================] - 0s 301us/step - loss: 0.1377 - mse: 0.0347 - val_loss: 0.1369 - val_mse: 0.0377
# Epoch 44/64
# 1081/1081 [==============================] - 0s 320us/step - loss: 0.1371 - mse: 0.0341 - val_loss: 0.1361 - val_mse: 0.0374
# Epoch 45/64
# 1081/1081 [==============================] - 0s 309us/step - loss: 0.1401 - mse: 0.0357 - val_loss: 0.1359 - val_mse: 0.0374
# Epoch 46/64
# 1081/1081 [==============================] - 0s 297us/step - loss: 0.1386 - mse: 0.0347 - val_loss: 0.1372 - val_mse: 0.0381
# Epoch 47/64
# 1081/1081 [==============================] - 0s 298us/step - loss: 0.1356 - mse: 0.0339 - val_loss: 0.1362 - val_mse: 0.0377
# Epoch 48/64
# 1081/1081 [==============================] - 0s 305us/step - loss: 0.1355 - mse: 0.0331 - val_loss: 0.1362 - val_mse: 0.0374
# Epoch 49/64
# 1081/1081 [==============================] - 0s 295us/step - loss: 0.1371 - mse: 0.0344 - val_loss: 0.1358 - val_mse: 0.0373
# Epoch 50/64
# 1081/1081 [==============================] - 0s 295us/step - loss: 0.1360 - mse: 0.0337 - val_loss: 0.1381 - val_mse: 0.0387
# Epoch 51/64
# 1081/1081 [==============================] - 0s 310us/step - loss: 0.1368 - mse: 0.0338 - val_loss: 0.1393 - val_mse: 0.0393
# Epoch 52/64
# 1081/1081 [==============================] - 0s 298us/step - loss: 0.1382 - mse: 0.0341 - val_loss: 0.1353 - val_mse: 0.0367
# Epoch 53/64
# 1081/1081 [==============================] - 0s 316us/step - loss: 0.1329 - mse: 0.0326 - val_loss: 0.1364 - val_mse: 0.0374
# Epoch 54/64
# 1081/1081 [==============================] - 0s 312us/step - loss: 0.1395 - mse: 0.0343 - val_loss: 0.1364 - val_mse: 0.0375
# Epoch 55/64
# 1081/1081 [==============================] - 0s 300us/step - loss: 0.1358 - mse: 0.0331 - val_loss: 0.1371 - val_mse: 0.0379
# Epoch 56/64
# 1081/1081 [==============================] - 0s 294us/step - loss: 0.1349 - mse: 0.0336 - val_loss: 0.1383 - val_mse: 0.0388
# Epoch 57/64
# 1081/1081 [==============================] - 0s 311us/step - loss: 0.1361 - mse: 0.0338 - val_loss: 0.1374 - val_mse: 0.0379
# Epoch 58/64
# 1081/1081 [==============================] - 0s 309us/step - loss: 0.1382 - mse: 0.0351 - val_loss: 0.1363 - val_mse: 0.0376
# Epoch 59/64
# 1081/1081 [==============================] - 0s 302us/step - loss: 0.1357 - mse: 0.0330 - val_loss: 0.1377 - val_mse: 0.0384
# Epoch 60/64
# 1081/1081 [==============================] - 0s 306us/step - loss: 0.1351 - mse: 0.0324 - val_loss: 0.1378 - val_mse: 0.0384
# Epoch 61/64
# 1081/1081 [==============================] - 0s 302us/step - loss: 0.1335 - mse: 0.0333 - val_loss: 0.1394 - val_mse: 0.0396
# Epoch 62/64
# 1081/1081 [==============================] - 0s 301us/step - loss: 0.1383 - mse: 0.0349 - val_loss: 0.1361 - val_mse: 0.0373
# Epoch 63/64
# 1081/1081 [==============================] - 0s 309us/step - loss: 0.1364 - mse: 0.0340 - val_loss: 0.1368 - val_mse: 0.0379
# Epoch 64/64
# 1081/1081 [==============================] - 0s 303us/step - loss: 0.1360 - mse: 0.0334 - val_loss: 0.1371 - val_mse: 0.0381

# %%
#loss: 0.0452 - MSE: 0.0452 - val_loss: 0.0424 - val_MSE: 0.0424  2016

results=model.predict([valid_data['dia'],valid_data['mes'], valid_data['year'], valid_continuas])

compara = pd.DataFrame(np.array([valid_target, [x[0] for x in results]])).transpose()
compara.columns = ['real', 'prediccion']

inverted = scaler.inverse_transform(compara.values)

compara2 = pd.DataFrame(inverted)
compara2.columns = ['real', 'prediccion']
compara2['diferencia'] = compara2['real'] - compara2['prediccion']
compara2.head(7)
# Out:
#     real  prediccion  diferencia
# 0  126.0  113.000526   12.999474
# 1  106.0  105.863571    0.136429
# 2   57.0   62.904125   -5.904125
# 3   57.0  102.811234  -45.811234
# 4  102.0  101.854851    0.145149
# 5  103.0  110.158791   -7.158791
# 6  120.0  111.498810    8.501190

# %%
compara2.describe()
# Out:
#              real  prediccion  diferencia
# count  136.000000  136.000000  136.000000
# mean    99.448532  102.374321   -2.925791
# std     22.625721   16.697773   16.388536
# min     29.999998   60.060314  -67.817467
# 25%     86.750000  102.811234   -9.252245
# 50%    104.000000  107.177155   -1.741375
# 75%    112.000000  112.610975    7.520697
# max    157.000000  117.728775   43.035851

# %%
window = 60
plt.scatter(range(len(valid_target[-window:])),valid_target[-window:],c='b')
plt.scatter(range(len(results[-window:])),results[-window:],c='orange')
plt.title('validate')
plt.show()
compara2['real'][len(compara2)-window:].plot()
compara2['prediccion'][len(compara2)-window:].plot()

# %%
plt.plot(history.history['loss'])
plt.title('loss')
plt.plot(history.history['val_loss'])
plt.title('validate loss')
plt.show()

# %%
plt.title('Accuracy')
plt.plot(history.history['mse'])

plt.plot(history.history['val_mse'])
plt.show()
